# %% [markdown]
# # Lab 2 Linear Regression

# %%
import tensorflow as tf
tf.random.set_seed(777)

# %%
W=tf.Variable(tf.random.normal([1]), name="weight")
b=tf.Variable(tf.random.normal([1]), name="bias")

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
X=tf.placeholder(tf.float32, shape=[None])
Y=tf.placeholder(tf.float32, shape=[None])

# %%
hypothesis = X*W+b

# %%
cost = tf.reduce_mean(tf.square(hypothesis-Y))

# %%
train=tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
        
    for step in range(2001):
            _,cost_val,W_val,b_val=sess.run(
            [train,cost,W,b], feed_dict={X:[1,2,3], Y:[1,2,3]}
             )
            if step%20==0:
                print(step,cost_val,W_val,b_val)
            
    #Testing our model
    print(sess.run(hypothesis, feed_dict={X:[5]}))
    print(sess.run(hypothesis, feed_dict={X:[2.5]}))
    print(sess.run(hypothesis, feed_dict={X:[1.5, 3.5]}))
# Out:
# 0 3.9557216 [0.58597755] [-1.1319157]
# 20 0.11755153 [1.2608613] [-0.7903967]
# 40 0.07525446 [1.3110107] [-0.725797]
# 60 0.0680616 [1.302337] [-0.68907297]
# 80 0.061812054 [1.2886943] [-0.6564401]
# 100 0.056138694 [1.2751805] [-0.62556607]
# 120 0.050986033 [1.262253] [-0.59616446]
# 140 0.04630633 [1.2499287] [-0.5681467]
# 160 0.042056125 [1.2381829] [-0.5414458]
# 180 0.03819607 [1.2269893] [-0.51599985]
# 200 0.03469028 [1.2163216] [-0.4917497]
# 220 0.03150629 [1.2061554] [-0.46863934]
# 240 0.028614506 [1.1964668] [-0.44661507]
# 260 0.025988169 [1.1872336] [-0.42562586]
# 280 0.023602845 [1.1784341] [-0.40562296]
# 300 0.021436483 [1.1700484] [-0.38656002]
# 320 0.019468945 [1.1620566] [-0.36839312]
# 340 0.017682001 [1.1544406] [-0.35107994]
# 360 0.016059084 [1.1471826] [-0.33458045]
# 380 0.014585108 [1.1402655] [-0.31885642]
# 400 0.013246414 [1.1336734] [-0.3038713]
# 420 0.012030627 [1.1273913] [-0.28959045]
# 440 0.010926399 [1.1214043] [-0.2759807]
# 460 0.009923532 [1.1156988] [-0.26301062]
# 480 0.009012693 [1.1102613] [-0.25065]
# 500 0.008185467 [1.1050795] [-0.23887032]
# 520 0.007434163 [1.1001409] [-0.22764422]
# 540 0.0067518395 [1.0954348] [-0.21694572]
# 560 0.0061321184 [1.0909497] [-0.20675007]
# 580 0.005569288 [1.0866754] [-0.19703357]
# 600 0.0050581247 [1.082602] [-0.18777378]
# 620 0.0045938604 [1.0787199] [-0.17894895]
# 640 0.0041722213 [1.0750204] [-0.17053895]
# 660 0.003789275 [1.0714947] [-0.16252424]
# 680 0.00344148 [1.0681348] [-0.15488625]
# 700 0.0031256108 [1.0649326] [-0.14760718]
# 720 0.0028387327 [1.0618812] [-0.14067025]
# 740 0.0025781763 [1.0589728] [-0.13405931]
# 760 0.0023415396 [1.0562013] [-0.12775895]
# 780 0.0021266271 [1.0535601] [-0.12175476]
# 800 0.0019314418 [1.0510432] [-0.1160328]
# 820 0.0017541661 [1.0486443] [-0.11057976]
# 840 0.0015931615 [1.0463581] [-0.1053829]
# 860 0.0014469355 [1.0441794] [-0.10043029]
# 880 0.0013141289 [1.0421033] [-0.09571044]
# 900 0.0011935098 [1.0401244] [-0.09121241]
# 920 0.0010839665 [1.0382386] [-0.08692571]
# 940 0.0009844733 [1.0364416] [-0.08284045]
# 960 0.00089411164 [1.034729] [-0.0789472]
# 980 0.0008120467 [1.0330968] [-0.07523695]
# 1000 0.0007375137 [1.0315413] [-0.07170107]
# 1020 0.00066982146 [1.030059] [-0.06833138]
# 1040 0.00060834415 [1.0286465] [-0.06512003]
# 1060 0.00055250706 [1.0273001] [-0.06205962]
# 1080 0.0005017921 [1.0260171] [-0.05914299]
# 1100 0.00045573505 [1.0247945] [-0.05636348]
# 1120 0.00041390758 [1.0236292] [-0.05371465]
# 1140 0.00037592012 [1.0225189] [-0.05119034]
# 1160 0.00034141736 [1.0214605] [-0.04878466]
# 1180 0.00031008126 [1.0204519] [-0.04649197]
# 1200 0.00028161818 [1.0194905] [-0.04430696]
# 1220 0.00025577025 [1.0185747] [-0.0422246]
# 1240 0.0002322931 [1.0177016] [-0.04024017]
# 1260 0.00021097368 [1.0168698] [-0.03834899]
# 1280 0.00019160793 [1.0160769] [-0.0365467]
# 1300 0.0001740231 [1.0153214] [-0.03482915]
# 1320 0.0001580504 [1.0146013] [-0.03319231]
# 1340 0.00014354465 [1.0139152] [-0.0316324]
# 1360 0.00013036876 [1.0132611] [-0.03014574]
# 1380 0.00011840213 [1.012638] [-0.02872899]
# 1400 0.00010753641 [1.0120441] [-0.02737886]
# 1420 9.766442e-05 [1.011478] [-0.02609218]
# 1440 8.870073e-05 [1.0109385] [-0.02486593]
# 1460 8.0560334e-05 [1.0104246] [-0.02369737]
# 1480 7.31663e-05 [1.0099347] [-0.02258373]
# 1500 6.6451954e-05 [1.0094677] [-0.02152239]
# 1520 6.0351522e-05 [1.0090227] [-0.02051088]
# 1540 5.4811168e-05 [1.0085987] [-0.01954692]
# 1560 4.978123e-05 [1.0081947] [-0.0186283]
# 1580 4.5211917e-05 [1.0078095] [-0.01775289]
# 1600 4.1062012e-05 [1.0074425] [-0.01691856]
# 1620 3.7293263e-05 [1.0070928] [-0.01612345]
# 1640 3.3870732e-05 [1.0067594] [-0.01536576]
# 1660 3.076228e-05 [1.0064417] [-0.01464363]
# 1680 2.7938768e-05 [1.006139] [-0.0139554]
# 1700 2.537411e-05 [1.0058506] [-0.0132996]
# 1720 2.3045128e-05 [1.0055755] [-0.01267459]
# 1740 2.0930396e-05 [1.0053136] [-0.01207894]
# 1760 1.900923e-05 [1.0050639] [-0.01151133]
# 1780 1.726471e-05 [1.0048258] [-0.01097037]
# 1800 1.5679854e-05 [1.0045991] [-0.0104548]
# 1820 1.4240875e-05 [1.004383] [-0.0099635]
# 1840 1.2933756e-05 [1.004177] [-0.00949526]
# 1860 1.1747495e-05 [1.0039808] [-0.00904904]
# 1880 1.0668474e-05 [1.0037936] [-0.00862379]
# 1900 9.689665e-06 [1.0036154] [-0.00821852]
# 1920 8.800319e-06 [1.0034455] [-0.00783232]
# 1940 7.992734e-06 [1.0032835] [-0.00746425]
# 1960 7.2590833e-06 [1.0031292] [-0.00711345]
# 1980 6.593115e-06 [1.0029823] [-0.00677918]
# 2000 5.9879208e-06 [1.0028421] [-0.00646063]
# [5.0077314]
# [2.500643]
# [1.4978079 3.5034783]

# %%
#Fit the line with new training data
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for step in range(2001):
            _,cost_val,W_val,b_val = sess.run(
           [train, cost, W, b],
           feed_dict={X:[1,2,3,4,5], Y:[2.1, 3.1, 4.1,5.1,6.1]},
           )
            if step %20==0:
                print(step, cost_val, W_val, b_val)
        
#Testing our model
    print(sess.run(hypothesis, feed_dict={X:[5]}))
    print(sess.run(hypothesis, feed_dict={X:[2.5]}))
    print(sess.run(hypothesis, feed_dict={X:[1.5, 3.5]}))
# Out:
# 0 12.4113865 [0.58597755] [-1.1319157]
# 20 0.61486924 [1.5046549] [-0.7387971]
# 40 0.53676116 [1.4756316] [-0.61725736]
# 60 0.46875745 [1.4445004] [-0.50478774]
# 80 0.40936953 [1.4153898] [-0.39461845]
# 100 0.35750538 [1.3881855] [-0.30147305]
# 120 0.31221214 [1.3627629] [-0.2096895]
# 140 0.2726571 [1.3390054] [-0.12391687]
# 160 0.23811345 [1.3168036] [-0.04376155]
# 180 0.20794626 [1.2960559] [0.03114427]
# 200 0.18160096 [1.2766669] [0.10114451]
# 220 0.15859349 [1.2585478] [0.16656035]
# 240 0.13850091 [1.2416153] [0.22769207]
# 260 0.12095392 [1.2257918] [0.28482014]
# 280 0.10562988 [1.2110044] [0.33820692]
# 300 0.0922474 [1.1971856] [0.38809738]
# 320 0.08056036 [1.1842717] [0.4347205]
# 340 0.07035394 [1.1722037] [0.47829017]
# 360 0.061440594 [1.1609259] [0.51900643]
# 380 0.053656567 [1.1503867] [0.5570561]
# 400 0.046858672 [1.1405379] [0.5926139]
# 420 0.040922064 [1.131334] [0.62584287]
# 440 0.03573753 [1.1227326] [0.6568959]
# 460 0.031209871 [1.114695] [0.68591505]
# 480 0.027255822 [1.1071835] [0.71303374]
# 500 0.023802703 [1.1001638] [0.73837656]
# 520 0.020787086 [1.093604] [0.7620595]
# 540 0.018153492 [1.0874739] [0.78419155]
# 560 0.01585357 [1.0817451] [0.8048741]
# 580 0.013845077 [1.0763916] [0.824202]
# 600 0.0120910015 [1.0713886] [0.84226424]
# 620 0.0105591435 [1.0667133] [0.8591437]
# 640 0.009221393 [1.0623443] [0.8749175]
# 660 0.008053117 [1.0582613] [0.8896582]
# 680 0.007032846 [1.0544456] [0.90343374]
# 700 0.006141823 [1.0508798] [0.9163072]
# 720 0.0053637014 [1.0475477] [0.92833745]
# 740 0.0046841525 [1.0444338] [0.9395796]
# 760 0.0040907115 [1.0415238] [0.9500857]
# 780 0.0035724398 [1.0388044] [0.95990384]
# 800 0.0031198452 [1.036263] [0.96907884]
# 820 0.00272459 [1.0338882] [0.9776529]
# 840 0.0023793995 [1.0316689] [0.9856654]
# 860 0.002077954 [1.0295948] [0.9931531]
# 880 0.0018146916 [1.0276567] [1.0001507]
# 900 0.0015847888 [1.0258454] [1.0066898]
# 920 0.0013840082 [1.0241529] [1.0128007]
# 940 0.0012086534 [1.022571] [1.0185118]
# 960 0.0010555265 [1.0210929] [1.0238484]
# 980 0.00092180556 [1.0197113] [1.0288357]
# 1000 0.0008050158 [1.0184205] [1.0334963]
# 1020 0.00070302497 [1.0172141] [1.0378517]
# 1040 0.00061395427 [1.0160867] [1.0419219]
# 1060 0.000536167 [1.015033] [1.0457257]
# 1080 0.00046824425 [1.0140486] [1.0492799]
# 1100 0.00040891898 [1.0131285] [1.0526017]
# 1120 0.00035711462 [1.0122688] [1.0557059]
# 1140 0.0003118645 [1.0114653] [1.0586067]
# 1160 0.00027235912 [1.0107145] [1.0613174]
# 1180 0.00023785148 [1.0100126] [1.0638508]
# 1200 0.00020772242 [1.009357] [1.066218]
# 1220 0.00018140387 [1.0087441] [1.0684304]
# 1240 0.0001584219 [1.0081717] [1.0704978]
# 1260 0.00013835382 [1.0076364] [1.0724299]
# 1280 0.00012082461 [1.0071363] [1.0742354]
# 1300 0.00010551802 [1.0066689] [1.0759227]
# 1320 9.2150534e-05 [1.0062323] [1.0774995]
# 1340 8.0474434e-05 [1.0058241] [1.078973]
# 1360 7.02811e-05 [1.0054427] [1.0803499]
# 1380 6.137823e-05 [1.0050863] [1.0816368]
# 1400 5.3600408e-05 [1.0047531] [1.0828394]
# 1420 4.6810193e-05 [1.0044419] [1.0839633]
# 1440 4.087873e-05 [1.004151] [1.0850135]
# 1460 3.570028e-05 [1.0038792] [1.0859951]
# 1480 3.11762e-05 [1.003625] [1.0869123]
# 1500 2.7227836e-05 [1.0033877] [1.0877693]
# 1520 2.3777558e-05 [1.0031658] [1.0885702]
# 1540 2.0766378e-05 [1.0029585] [1.0893186]
# 1560 1.8134899e-05 [1.0027647] [1.0900184]
# 1580 1.5837762e-05 [1.0025837] [1.0906719]
# 1600 1.3831433e-05 [1.0024145] [1.0912828]
# 1620 1.2079043e-05 [1.0022564] [1.0918537]
# 1640 1.0548495e-05 [1.0021086] [1.0923873]
# 1660 9.211951e-06 [1.0019705] [1.0928859]
# 1680 8.044999e-06 [1.0018415] [1.0933516]
# 1700 7.025957e-06 [1.0017209] [1.093787]
# 1720 6.1355445e-06 [1.0016081] [1.0941939]
# 1740 5.3584386e-06 [1.0015029] [1.0945741]
# 1760 4.679775e-06 [1.0014045] [1.0949293]
# 1780 4.086869e-06 [1.0013125] [1.0952615]
# 1800 3.5689961e-06 [1.0012265] [1.0955716]
# 1820 3.1174113e-06 [1.0011462] [1.0958617]
# 1840 2.722258e-06 [1.0010712] [1.0961326]
# 1860 2.3772895e-06 [1.001001] [1.096386]
# 1880 2.0762425e-06 [1.0009354] [1.0966225]
# 1900 1.8135727e-06 [1.0008744] [1.0968435]
# 1920 1.5840491e-06 [1.0008172] [1.0970501]
# 1940 1.3832014e-06 [1.0007635] [1.0972431]
# 1960 1.2078377e-06 [1.0007136] [1.0974237]
# 1980 1.0550366e-06 [1.000667] [1.0975924]
# 2000 9.2145604e-07 [1.0006232] [1.09775]
# [6.1008625]
# [3.5993102]
# [2.598689  4.5999317]
